# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
x = np.arange(0.001, 4, 0.1)
#y = np.log(15*x) -2*x**2

def fun(a):
    return np.log(15*a) -2*a**2

plt.figure()
plt.plot(x, fun(x), linewidth = 1)
plt.scatter(0.5, fun(0.5))
plt.xlabel('x')
plt.ylabel('log$(15x) - 2x^2$')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

ax = Axes3D(fig)

l1 = 0
u1 = 3
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(l1, u1, 0.25)
X1, X2 = np.meshgrid(x1, x2)
#plt.fill_between(x1, 5-0.5*x1,  alpha = 0.3, color = 'red')
y = 2*np.ones(len(x1))

def fun(x, y):
    return  - (x-2)**2 - (y -2)**2 +10 
V = fun(X1, X2)
ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)
#

plt.plot(x1, y, ':',  c = 'red')
plt.plot(x1, y, 10*np.ones(len(x1)), ':',  c = 'red')
plt.plot(x1, y, fun(x1, y), '-',  c = 'red')

plt.plot(y, x1,':',  c = 'green')
plt.plot(y, x1,10*np.ones(len(x1)), ':',  c = 'green')
#plt.plot([2], [2], 'o', c = 'red')

plt.plot(y, x1, fun(y, x1), '-',  c = 'green')
plt.plot([2], [2] , fun(2, 2), 'o', c = 'red')


plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
ax.zaxis.set_rotate_label(False) 
ax.set_zlabel('$f({x_1}, x_2)$', rotation = 90)
ax.view_init(30, 260)
#plt.contour(X1, X2, V, cmap = 'viridis')
#plt.contour(X1, X2, V, 50,  linewidths = 0.5, colors = 'k')
name = 'Multivariate FOC'
plt.title(name)
#fig.savefig(name + '.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

ax = Axes3D(fig)

l1 = 0
u1 = 3
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(l1, u1, 0.25)
X1, X2 = np.meshgrid(x1, x2)
#plt.fill_between(x1, 5-0.5*x1,  alpha = 0.3, color = 'red')
y = 2*np.ones(len(x1))

def fun(x, y):
    return  - (x-2)**2 - (y -2)**2 + 10
V = fun(X1, X2)
ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)
#
y = 3-x1
plt.plot(x1, y,':',  c = 'blue')
plt.plot(x1, y, fun(x1, y), '-',  c = 'blue')

#plt.plot(y, x1,':',  c = 'green')
#plt.plot([2], [2], 'o', c = 'red')

#plt.plot(y, x1, fun(y, x1), '-',  c = 'green')
plt.plot([2], [2] , fun(2, 2), 'o', c = 'red')
plt.plot([1.5], [1.5] , fun(1.5, 1.5), 'o', c = 'blue')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
ax.zaxis.set_rotate_label(False) 
ax.set_zlabel('$f({x_1}, x_2)$', rotation = 90)
ax.view_init(30, 260)
#plt.contour(X1, X2, V, cmap = 'viridis')
#plt.contour(X1, X2, V, 35,  linewidths = 0.5, colors = 'k')

name = 'Constrained Maximization'
plt.title(name)
fig.savefig(name + '.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

ax = Axes3D(fig)

l1 = 0
u1 = 3
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(l1, u1, 0.25)
X1, X2 = np.meshgrid(x1, x2)
#plt.fill_between(x1, 5-0.5*x1,  alpha = 0.3, color = 'red')
y = 2*np.ones(len(x1))

def fun(x, y):
    return  - (x-2)**2 - (y -2)**2 + 10
V = fun(X1, X2)
#ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)
#
y = 3-x1
plt.plot(x1, y,':',  c = 'blue')
plt.plot(x1, y, fun(x1, y), '-',  c = 'blue')

#plt.plot(y, x1,':',  c = 'green')
#plt.plot([2], [2], 'o', c = 'red')

#plt.plot(y, x1, fun(y, x1), '-',  c = 'green')
plt.plot([2], [2] , fun(2, 2), 'o', c = 'red')
plt.plot([1.5], [1.5] , fun(1.5, 1.5), 'o', c = 'blue')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
ax.zaxis.set_rotate_label(False) 
ax.set_zlabel('$f({x_1}, x_2)$', rotation = 90)
ax.view_init(30, 260)
#plt.contour(X1, X2, V, cmap = 'viridis')
plt.contour(X1, X2, V, 35,  linewidths = 0.5, colors = 'k')

name = 'Constrained Maximization (a graph with contours)'
plt.title(name)
fig.savefig(name + '.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

ax = Axes3D(fig)

l1 = 0
u1 = 3
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(l1, u1, 0.25)
X1, X2 = np.meshgrid(x1, x2)
#plt.fill_between(x1, 5-0.5*x1,  alpha = 0.3, color = 'red')
y = 2*np.ones(len(x1))

def fun(x, y):
    return  - (x-2)**2 - (y -2)**2 + 10
V = fun(X1, X2)
#ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)
#
y = 3-x1
plt.plot(x1, y,':',  c = 'blue')
plt.plot(x1, y, fun(x1, y), '-',  c = 'blue')

#plt.plot(y, x1,':',  c = 'green')
#plt.plot([2], [2], 'o', c = 'red')

#plt.plot(y, x1, fun(y, x1), '-',  c = 'green')
plt.plot([2], [2] , fun(2, 2), 'o', c = 'red')
plt.plot([1.5], [1.5] , fun(1.5, 1.5), 'o', c = 'blue')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')

ax.zaxis.set_rotate_label(False) 
ax.set_zlabel('$f({x_1}, x_2)$', rotation = 90)
ax.view_init(0, 270)
#plt.contour(X1, X2, V, cmap = 'viridis')
plt.contour(X1, X2, V, 35,  linewidths = 0.5, colors = 'k')

name = 'Constrained Maximization (Intuition of Method 1)'
plt.title(name)
fig.savefig(name + '.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

ax = Axes3D(fig)

l1 = 0
u1 = 3
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(l1, u1, 0.25)
X1, X2 = np.meshgrid(x1, x2)
#plt.fill_between(x1, 5-0.5*x1,  alpha = 0.3, color = 'red')
y = 2*np.ones(len(x1))

def fun(x, y):
    return  - (x-2)**2 - (y -2)**2 + 10
V = fun(X1, X2)
#ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)
#
y = 3-x1
plt.plot(x1, y,':',  c = 'blue')
plt.plot(x1, y, fun(x1, y), '-',  c = 'blue')

#plt.plot(y, x1,':',  c = 'green')
#plt.plot([2], [2], 'o', c = 'red')

#plt.plot(y, x1, fun(y, x1), '-',  c = 'green')
plt.plot([2], [2] , fun(2, 2), 'o', c = 'red')
plt.plot([1.5], [1.5] , fun(1.5, 1.5), 'o', c = 'blue')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
ax.zaxis.set_rotate_label(False) 
ax.set_zlabel('$f({x_1}, x_2)$', rotation = 90)
ax.view_init(90, 270)
#plt.contour(X1, X2, V, cmap = 'viridis')
plt.contour(X1, X2, V, 35,  linewidths = 0.5, colors = 'k')

name = 'Constrained Maximization (Intuition of Method 2)'
plt.title(name)
fig.savefig(name + '.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

ax = Axes3D(fig)

l1 = 0
u1 = 10
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(5-0.5*u1, 5-0.5*l1, 0.25)
X1, X2 = np.meshgrid(x1, x2)
plt.plot(x1, 5-0.5*x1,':',  c = 'red')
#plt.fill_between(x1, 5-0.5*x1,  alpha = 0.3, color = 'red')
def fun(x, y):
    return x**3 +8*y
V = fun(X1, X2)
ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)
#
y = 5-0.5*x1
plt.plot(x1, y, fun(x1, y), ':',  c = 'red')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')

ax.zaxis.set_rotate_label(False) 
ax.set_zlabel('${x_1}^3 + 8x_2$', rotation = 90)
ax.view_init(30, 240)
#plt.contour(X1, X2, V, cmap = 'viridis')
#plt.contour(X1, X2, V, 50,  linewidths = 0.5, colors = 'k')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()

l1 = 0
u1 = 10
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(5-0.5*u1, 5-0.5*l1, 0.25)
X1, X2 = np.meshgrid(x1, x2)
V = X1**3 +8*X2
CS = plt.contour(X1, X2, V, 50,  linewidths = 1, colors = 'k')
ax.clabel(CS, fontsize=7, inline=1, fmt='%1.1f')
#ax = Axes3D(fig)
#plt.colorbar()
#ax.contour(X1, X2, V, cmap = 'viridis')
#
plt.plot(x1, 5-0.5*x1,':',  c = 'red')
#plt.fill_between(x1, 5-0.5*x1, 5-0.5*u1,  alpha = 0.3, color = 'red')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()

l1 = 0
u1 = 3
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(5-0.5*u1, 5-0.5*l1, 0.25)
X1, X2 = np.meshgrid(x1, x2)
V = X1**3 +8*X2
CS = plt.contour(X1, X2, V, 20,  linewidths = 1, colors = 'k')
ax.clabel(CS, fontsize=7, inline=1, fmt='%1.1f')
#ax = Axes3D(fig)
#plt.colorbar()
#ax.contour(X1, X2, V, cmap = 'viridis')
#
plt.plot(x1, 5-0.5*x1,':',  c = 'red')
#plt.fill_between(x1, 5-0.5*x1, 5-0.5*u1,  alpha = 0.3, color = 'red')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

ax = Axes3D(fig)

l1 = 0
u1 = 5
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(l1, u1, 0.25)
X1, X2 = np.meshgrid(x1, x2)
#plt.fill_between(x1, 5-0.5*x1,  alpha = 0.3, color = 'red')
y = 2*np.ones(len(x1))

def fun(x, y):
    return  (x**(1/3))*(y**(2/3))
V = fun(X1, X2)
ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)
#
y = 5-x1
plt.plot(x1, y,':',  c = 'blue')
plt.plot(x1, y, fun(x1, y), '-',  c = 'blue')

#plt.plot(y, x1,':',  c = 'green')
#plt.plot([2], [2], 'o', c = 'red')

#plt.plot(y, x1, fun(y, x1), '-',  c = 'green')
#plt.plot([2], [2] , fun(2, 2), 'o', c = 'red')
#plt.plot([1.5], [1.5] , fun(1.5, 1.5), 'o', c = 'blue')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
ax.zaxis.set_rotate_label(False) 
ax.set_zlabel('$f({x_1}, x_2)$', rotation = 90)
ax.view_init(30, 260)
#plt.contour(X1, X2, V, cmap = 'viridis')
#plt.contour(X1, X2, V, 35,  linewidths = 0.5, colors = 'k')

name = 'Constrained Maximization'
plt.title(name)
#fig.savefig(name + '.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Total Derivative

# %%
fig = plt.figure()

ax = Axes3D(fig)

l1 = 0
u1 = 3
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(l1, u1, 0.25)
X1, X2 = np.meshgrid(x1, x2)

def fun(x, y):
    return  - (x-2)**2 - (y -2)**2 + 10
V = fun(X1, X2)

def fun2(x, y):
    return   x + y + 6.5
V2 = fun2(X1, X2)

ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)
ax.plot_wireframe(X1, X2, V2,  rstride = 1, cstride = 1, linewidth = 0.5, color = 'green')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
ax.zaxis.set_rotate_label(False) 
ax.set_zlabel('$f({x_1}, x_2)$', rotation = 90)
ax.view_init(30, 260)

name = 'Total Differentiation'
plt.title(name)
#fig.savefig(name + '.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

ax = Axes3D(fig)

l1 = 0
u1 = 4
x1 = np.arange(l1, u1, 0.25)
x2 = np.arange(l1, u1, 0.25)
X1, X2 = np.meshgrid(x1, x2)

def fun(x, y):
    return  - (x-2)**2 - (y -2)**2 + 4*(x-2)*(y-2) + 10
V = fun(X1, X2)

ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)


y = 2*np.ones(len(x1))
plt.plot(x1, y, ':',  c = 'red')
plt.plot(x1, y, 10*np.ones(len(x1)), ':',  c = 'red')
plt.plot(x1, y, fun(x1, y), '-',  c = 'red')

plt.plot(y, x1,':',  c = 'green')
plt.plot(y, x1,10*np.ones(len(x1)), ':',  c = 'green')
plt.plot(y, x1, fun(y, x1), '-',  c = 'green')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
ax.zaxis.set_rotate_label(False) 
ax.set_zlabel('$f({x_1}, x_2)$', rotation = 90)
ax.view_init(30, 260)

name = 'What if $f_{11}<0, f_{22}<0$, but $f_{11}f_{22} - f_{12}^2 <0 $?'
plt.title(name)
#fig.savefig('what if SOC is not satisfied' + '.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.animation as animation

n = 40

# %%
def fun(x, y, al):
    return  - (x-2)**2 - (y -2)**2 + 0.1*al*(x-2)*(y-2) + 10

def sod(x, y, al):
    return  4-(0.1*al)**2

def update(curr):
    if curr == 30:
        a.event_source.stop()
    plt.cla()   
    ax = Axes3D(fig)
    l1 = 0
    u1 = 4
    x1 = np.arange(l1, u1, 0.25)
    x2 = np.arange(l1, u1, 0.25)
    X1, X2 = np.meshgrid(x1, x2)
    V = fun(X1, X2, curr)
    ax.plot_wireframe(X1, X2, V,  rstride = 1, cstride = 1, linewidth = 0.5)
    sod_s = str(sod(2, 2, curr))[:5]
    ax.text(0,4,11, r'$f_{11}=-2<0$, $f_{22}=-2<0$, and $f_{11}f_{22}-f_{12}^2=$'+sod_s)#
    #plt.annotate
    y = 2*np.ones(len(x1))
    plt.plot(x1, y, ':',  c = 'red')
    plt.plot(x1, y, 10*np.ones(len(x1)), ':',  c = 'red')
    plt.plot(x1, y, fun(x1, y, curr), '-',  c = 'red')
    plt.plot(y, x1,':',  c = 'green')
    plt.plot(y, x1,10*np.ones(len(x1)), ':',  c = 'green')
    plt.plot(y, x1, fun(y, x1, curr), '-',  c = 'green')
    plt.xlabel('$x_1$')
    plt.ylabel('$x_2$')
    ax.zaxis.set_rotate_label(False) 
    ax.set_zlabel('$f(x_1, x_2)$', rotation = 90)
    ax.view_init(30, 260)
    ax.set_zlim(0,12)
    #name = 'What if $f_{11}<0, f_{22}<0$, but $f_{11}f_{22} - 2f_{12} <0 $?'
    #plt.title(name)
    #print()

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval =300, frames = 30)
#plt.show()
#ax = plt.gca()
#ax.annotate('annotate here!', [0,0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sod(2,2,40)
# Out:
# -4.0

# %% [markdown]
# $x_1$ $\alpha$
